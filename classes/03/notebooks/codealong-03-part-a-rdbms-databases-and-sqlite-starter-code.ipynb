# %% [markdown]
# # DS-SF-34 | 03 | Databases, Scrapping, and APIs | Codealong | Starter Code

# %% [markdown]
# # Part A | RDBMS Databases and `SQLite`

# %%
import os

import pandas as pd
pd.set_option('display.max_rows', 10)
pd.set_option('display.notebook_repr_html', True)
pd.set_option('display.max_columns', 10)

import sqlite3

# %% [markdown]
# > ### How to connect to a `SQLite` database

# %%
db = sqlite3.connect(os.path.join('..', 'datasets', 'dataset-03-zillow.db'))

# %% [markdown]
# > ### How to use `pandas` to run SQL queries and get the results as a `DataFrame`

# %%
pd.io.sql.read_sql(
'''
SELECT *
    FROM properties
    LIMIT 10
;
''', con = db)
# Out:
#          id                                     address  latitude  longitude  \
# 0  15063471   55 Vandewater St APT 9, San Francisco, CA  37805103 -122412856
# 1  15063505         740 Francisco St, San Francisco, CA  37804420 -122417389
# 2  15063609         819 Francisco St, San Francisco, CA  37803728 -122419055
# 3  15064044    199 Chestnut St APT 5, San Francisco, CA  37804392 -122406590
# 4  15064257  111 Chestnut St APT 403, San Francisco, CA  37804240 -122405509
# 5  15064295  111 Chestnut St APT 702, San Francisco, CA  37804240 -122405509
# 6  15064391   1821 Grant Ave APT 101, San Francisco, CA  37803748 -122408531
# 7  15064536      2300 Leavenworth St, San Francisco, CA  37802408 -122417537
# 8  15064640     1047-1049 Lombard St, San Francisco, CA  37801889 -122418704
# 9  15064669      1055 Lombard St # C, San Francisco, CA  37801873 -122418834
#
#    is_a_studio      ...          size  size_unit  lot_size lot_size_unit  \
# 0            0      ...         550.0       sqft       NaN          None
# 1            0      ...        1430.0       sqft    2435.0          sqft
# 2            0      ...        2040.0       sqft    3920.0          sqft
# 3            0      ...        1060.0       sqft       NaN          None
# 4            0      ...        1299.0       sqft       NaN          None
# 5            0      ...        1033.0       sqft       NaN          None
# 6            0      ...        1048.0       sqft       NaN          None
# 7            0      ...        2115.0       sqft    1271.0          sqft
# 8            1      ...        4102.0       sqft    3049.0          sqft
# 9            0      ...        1182.0       sqft       NaN          None
#
#    built_in_year
# 0         1980.0
# 1         1948.0
# 2         1976.0
# 3         1930.0
# 4         1993.0
# 5         1993.0
# 6         1975.0
# 7         1913.0
# 8         1948.0
# 9         1986.0
#
# [10 rows x 12 columns]

# %% [markdown]
# ### `SELECT`

# %%
pd.io.sql.read_sql(
'''
SELECT id, sale_price, sale_price_unit
    FROM transactions
;
''', con = db)
# Out:
#              id  sale_price sale_price_unit
# 0      15063471   710000.00               $
# 1      15063505        2.15              $M
# 2      15063609        5.60              $M
# 3      15064044        1.50              $M
# 4      15064257   970000.00               $
# ..          ...         ...             ...
# 995  2124214951   390000.00               $
# 996  2126960082   860000.00               $
# 997  2128308939   830000.00               $
# 998  2131957929   835000.00               $
# 999  2136213970   825000.00               $
#
# [1000 rows x 3 columns]

# %% [markdown]
# ### `WHERE`

# %%
pd.io.sql.read_sql(
'''
SELECT id, sale_price
    FROM transactions
    WHERE sale_price_unit = '$M'
;
''', con = db)
# Out:
#              id  sale_price
# 0      15063505        2.15
# 1      15063609        5.60
# 2      15064044        1.50
# 3      15064536        2.83
# 4      15064640        4.05
# ..          ...         ...
# 570  2106229715        1.24
# 571  2108411930        1.73
# 572  2108546010        1.40
# 573  2121221385        1.43
# 574  2122992200        2.75
#
# [575 rows x 2 columns]

# %% [markdown]
# > #### Here's let's convert the unit of `sale_price` from \$ to \$M

# %%
pd.io.sql.read_sql(
'''
SELECT id, sale_price / 1000000 AS sale_price
    FROM transactions
    WHERE sale_price_unit = '$'
;
''', con = db)
# Out:
#              id  sale_price
# 0      15063471       0.710
# 1      15064257       0.970
# 2      15064295       0.940
# 3      15064391       0.835
# 4      15065032       0.800
# ..          ...         ...
# 420  2124214951       0.390
# 421  2126960082       0.860
# 422  2128308939       0.830
# 423  2131957929       0.835
# 424  2136213970       0.825
#
# [425 rows x 2 columns]

# %% [markdown]
# ### `UNION`

# %% [markdown]
# > #### Let's combine the previous two queries into one.  `sale_price` is now in \$M accross the dataset

# %%
pd.io.sql.read_sql('''
SELECT id, sale_price / 1000000 AS sale_price
    FROM transactions
    WHERE sale_price_unit = '$'
UNION ALL
SELECT id, sale_price
    FROM transactions
    WHERE sale_price_unit = '$M'
;
''', con = db)
# Out:
#              id  sale_price
# 0      15063471       0.710
# 1      15064257       0.970
# 2      15064295       0.940
# 3      15064391       0.835
# 4      15065032       0.800
# ..          ...         ...
# 995  2106229715       1.240
# 996  2108411930       1.730
# 997  2108546010       1.400
# 998  2121221385       1.430
# 999  2122992200       2.750
#
# [1000 rows x 2 columns]

# %% [markdown]
# ### `WITH`

# %%
pd.io.sql.read_sql(
'''
WITH normalized_sale_prices AS
    (SELECT id, sale_price / 1000000 AS sale_price
        FROM transactions
        WHERE sale_price_unit = '$'
    UNION ALL
    SELECT id, sale_price
        FROM transactions
        WHERE sale_price_unit = '$M')

SELECT *
    FROM normalized_sale_prices
;
''', con = db)
# Out:
#              id  sale_price
# 0      15063471       0.710
# 1      15064257       0.970
# 2      15064295       0.940
# 3      15064391       0.835
# 4      15065032       0.800
# ..          ...         ...
# 995  2106229715       1.240
# 996  2108411930       1.730
# 997  2108546010       1.400
# 998  2121221385       1.430
# 999  2122992200       2.750
#
# [1000 rows x 2 columns]

# %% [markdown]
# ### `JOIN`

# %%
pd.io.sql.read_sql(
'''
WITH normalized_sale_prices AS
    (SELECT id, sale_price / 1000000 AS sale_price
        FROM transactions
        WHERE sale_price_unit = '$'
    UNION ALL
    SELECT id, sale_price
        FROM transactions
        WHERE sale_price_unit = '$M')

SELECT properties.beds AS beds, normalized_sale_prices.sale_price AS sale_price
    FROM properties
    JOIN normalized_sale_prices
        ON normalized_sale_prices.id = properties.id
;
''', con = db)
# Out:
#      beds  sale_price
# 0     1.0       0.710
# 1     2.0       0.970
# 2     2.0       0.940
# 3     1.0       0.835
# 4     1.0       0.800
# ..    ...         ...
# 995   3.0       1.240
# 996   2.0       1.730
# 997   2.0       1.400
# 998   NaN       1.430
# 999   NaN       2.750
#
# [1000 rows x 2 columns]

# %% [markdown]
# ### `WITH` (take 2)

# %%
pd.io.sql.read_sql(
'''
WITH normalized_sale_prices AS
    (SELECT id, sale_price / 1000000 AS sale_price
        FROM transactions
        WHERE sale_price_unit = '$'
    UNION ALL
    SELECT id, sale_price
        FROM transactions
        WHERE sale_price_unit = '$M'),

beds_normalized_sale_prices AS
    (SELECT properties.beds AS beds, normalized_sale_prices.sale_price AS sale_price
        FROM properties
        JOIN normalized_sale_prices
            ON normalized_sale_prices.id = properties.id)

SELECT *
    FROM beds_normalized_sale_prices
;
''', con = db)
# Out:
#      beds  sale_price
# 0     1.0       0.710
# 1     2.0       0.970
# 2     2.0       0.940
# 3     1.0       0.835
# 4     1.0       0.800
# ..    ...         ...
# 995   3.0       1.240
# 996   2.0       1.730
# 997   2.0       1.400
# 998   NaN       1.430
# 999   NaN       2.750
#
# [1000 rows x 2 columns]

# %% [markdown]
# ### `GROUP BY` and `AVG`

# %% [markdown]
# > ### Let's now compute the average sale price of these properties based on their number of bedrooms

# %%
pd.io.sql.read_sql(
'''
WITH normalized_sale_prices AS
    (SELECT id, sale_price / 1000000 AS sale_price
        FROM transactions
        WHERE sale_price_unit = '$'
    UNION ALL
    SELECT id, sale_price
        FROM transactions
        WHERE sale_price_unit = '$M'),

beds_normalized_sale_prices AS
    (SELECT properties.beds AS beds, normalized_sale_prices.sale_price AS sale_price
        FROM properties
        JOIN normalized_sale_prices
            ON normalized_sale_prices.id = properties.id)

SELECT AVG(sale_price) AS mean_sale_price
    FROM beds_normalized_sale_prices
    GROUP BY beds
;
''', con = db)
# Out:
#    mean_sale_price
# 0         1.494858
# 1         0.820425
# 2         1.192398
# 3         1.404323
# 4         1.879330
# 5         2.867720
# 6         2.587222
# 7         5.543167
# 8         1.960000
# 9         1.766667

# %% [markdown]
# Note: `beds = 0` usually refers to studios but not always...

# %% [markdown]
# > ### Activity
# > #### Compute the average sales price of studios

# %%
pd.io.sql.read_sql(
'''
WITH normalized_sale_prices AS
    (SELECT id, sale_price / 1000000 AS sale_price
        FROM transactions
        WHERE sale_price_unit = '$'
    UNION ALL
    SELECT id, sale_price
        FROM transactions
        WHERE sale_price_unit = '$M'),

beds_normalized_sale_prices AS
    (SELECT properties.is_a_studio, properties.beds AS beds, normalized_sale_prices.sale_price AS sale_price
        FROM properties
        JOIN normalized_sale_prices
            ON normalized_sale_prices.id = properties.id)

SELECT AVG(sale_price)
    FROM beds_normalized_sale_prices
    WHERE is_a_studio = 1
;
''', con = db)
# Out:
#    AVG(sale_price)
# 0         1.464034

# %% [markdown]
# > ### Activity
# > #### Find the properties in the dataset that have different addresses but the same latitude/longitude.  Return the smallest set of pair of properties (`address_a`, `address_b`)

# %%
pd.io.sql.read_sql(
'''
SELECT id_lat_long AS (SELECT id, latitude, longitude
    FROM properties)
    
SELECT * 
    FROM id_lat_long AS a, id_lat_long AS b
    WHERE (a.latitude = b.latitude) AND (a.longitude = b.longitude)
;
''', con = db)
# Out:
# ERROR:root:An unexpected error occurred while tokenizing input
# The following traceback may be corrupted or invalid
# The error message is: ('EOF in multi-line string', (1, 0))
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# /Users/nathanmaas/anaconda/lib/python3.6/site-packages/pandas/io/sql.py in execute(self, *args, **kwargs)
#    1400             else:
# -> 1401                 cur.execute(*args)
#    1402             return cur
#
# OperationalError: near "(": syntax error
#
# During handling of the above exception, another exception occurred:
#
# DatabaseError                             Traceback (most recent call last)
# <ipython-input-14-6e008ec6ef76> in <module>()
#       8     WHERE (a.latitude = b.latitude) AND (a.longitude = b.longitude)
#       9 ;
# ---> 10 ''', con = db)
#
# /Users/nathanmaas/anaconda/lib/python3.6/site-packages/pandas/io/sql.py in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize)
#     397             sql, index_col=index_col, params=params,
#     398             coerce_float=coerce_float, parse_dates=parse_dates,
# --> 399             chunksize=chunksize)
#     400
#     401     try:
#
# /Users/nathanmaas/anaconda/lib/python3.6/site-packages/pandas/io/sql.py in read_query(self, sql, index_col, coerce_float, params, parse_dates, chunksize)
#    1434
#    1435         args = _convert_params(sql, params)
# -> 1436         cursor = self.execute(*args)
#    1437         columns = [col_desc[0] for col_desc in cursor.description]
#    1438
#
# /Users/nathanmaas/anaconda/lib/python3.6/site-packages/pandas/io/sql.py in execute(self, *args, **kwargs)
#    1411             ex = DatabaseError(
#    1412                 "Execution failed on sql '%s': %s" % (args[0], exc))
# -> 1413             raise_with_traceback(ex)
#    1414
#    1415     @staticmethod
#
# /Users/nathanmaas/anaconda/lib/python3.6/site-packages/pandas/compat/__init__.py in raise_with_traceback(exc, traceback)
#     338         if traceback == Ellipsis:
#     339             _, _, traceback = sys.exc_info()
# --> 340         raise exc.with_traceback(traceback)
#     341 else:
#     342     # this version of raise is a syntax error in Python 3
#
# /Users/nathanmaas/anaconda/lib/python3.6/site-packages/pandas/io/sql.py in execute(self, *args, **kwargs)
#    1399                 cur.execute(*args, **kwargs)
#    1400             else:
# -> 1401                 cur.execute(*args)
#    1402             return cur
#    1403         except Exception as exc:
#
# DatabaseError: Execution failed on sql '
# SELECT id_lat_long AS (SELECT id, latitude, longitude
#     FROM properties)
#
# SELECT *
#     FROM id_lat_long AS a, id_lat_long AS b
#     WHERE (a.latitude = b.latitude) AND (a.longitude = b.longitude)
# ;
# ': near "(": syntax error
