# %%
import pandas as pd
import numpy as np
import os

# %%
df = pd.read_csv(os.path.join('..', 'datasets', 'dataset-06-storms.csv.gz'), low_memory=False, encoding='latin')

# %%
df
# Out:
#         STATE__            BGN_DATE     BGN_TIME TIME_ZONE  COUNTY  \
# 0           1.0   4/18/1950 0:00:00          130       CST    97.0
# 1           1.0   4/18/1950 0:00:00          145       CST     3.0
# 2           1.0   2/20/1951 0:00:00         1600       CST    57.0
# 3           1.0    6/8/1951 0:00:00          900       CST    89.0
# 4           1.0  11/15/1951 0:00:00         1500       CST    43.0
# 5           1.0  11/15/1951 0:00:00         2000       CST    77.0
# 6           1.0  11/16/1951 0:00:00          100       CST     9.0
# 7           1.0   1/22/1952 0:00:00          900       CST   123.0
# 8           1.0   2/13/1952 0:00:00         2000       CST   125.0
# 9           1.0   2/13/1952 0:00:00         2000       CST    57.0
# 10          1.0   2/13/1952 0:00:00         2030       CST    43.0
# 11          1.0   2/13/1952 0:00:00         2030       CST     9.0
# 12          1.0   2/13/1952 0:00:00         2130       CST    73.0
# ...

# %%
df.isnull().sum()
df.BGN_AZI.isnull().sum()
# Out:
# 547332

# %%
df2 = df[ ['STATE', 'COUNTYNAME','EVTYPE', 'BGN_DATE', 'FATALITIES', 'INJURIES','PROPDMG', 'CROPDMG','PROPDMGEXP','CROPDMGEXP'] ]

# %%
df2.sort_values('FATALITIES', ascending=False)
# Out:
#        STATE                                         COUNTYNAME  \
# 198703    IL  ILZ003>006 - 008 - 010>014 - 019>023 - 032 - 0...
# 862633    MO                                             JASPER
# 68669     MI                                            GENESEE
# 148851    TX                                           MCLENNAN
# 355127    IL                   ILZ005>006 - 012>014 - 020 - 022
# 67883     MA                                          WORCESTER
# 46308     KS                                             COWLEY
# 371111    PA                     PAZ054>055 - 060>062 - 067>071
# 230926    PA                                         PAZ037>071
# 247937    WI                                         WIZ005>072
# 78566     MS                                              HINDS
# 6369      AR                                              WHITE
# 598499    TX                             TXZ163 - 199 - 213>214
# 606362    CA                               CAZ089>094 - 098>099
# ...

# %%
df2[(df2.FATALITIES >= 1) | (df2.INJURIES >=1) | (df2.PROPDMG >=1) | (df2.CROPDMG >=1)]
# Out:
#         STATE__            BGN_DATE     BGN_TIME TIME_ZONE  COUNTY  \
# 187565      1.0   10/4/1995 0:00:00         1200       CST     0.0
# 187570      1.0   6/26/1994 0:00:00         2025       CST    83.0
# 187580      1.0    8/3/1995 0:00:00          900       CST     0.0
# 187582      1.0   10/3/1995 0:00:00         1200       CST     0.0
# 187583      1.0   10/4/1995 0:00:00            0       CST     0.0
# 187652      1.0   3/24/1994 0:00:00         1410       CST     7.0
# 187653      1.0   3/24/1994 0:00:00         1425       CST     7.0
# 187679      1.0  11/28/1994 0:00:00           30       CST     9.0
# 187722      1.0   3/24/1994 0:00:00         1804       CST    17.0
# 187749      1.0    7/9/1995 0:00:00         1610       CST    19.0
# 187771      1.0   6/10/1994 0:00:00         1840       CST    25.0
# 187795      1.0    3/9/1994 0:00:00         1755       CST    31.0
# 187847      1.0    7/6/1994 0:00:00          800       CST    39.0
# ...

# %%
df2
# Out:
#         STATE__            BGN_DATE     BGN_TIME TIME_ZONE  COUNTY  \
# 187565      1.0   10/4/1995 0:00:00         1200       CST     0.0
# 187570      1.0   6/26/1994 0:00:00         2025       CST    83.0
# 187580      1.0    8/3/1995 0:00:00          900       CST     0.0
# 187582      1.0   10/3/1995 0:00:00         1200       CST     0.0
# 187583      1.0   10/4/1995 0:00:00            0       CST     0.0
# 187652      1.0   3/24/1994 0:00:00         1410       CST     7.0
# 187653      1.0   3/24/1994 0:00:00         1425       CST     7.0
# 187679      1.0  11/28/1994 0:00:00           30       CST     9.0
# 187722      1.0   3/24/1994 0:00:00         1804       CST    17.0
# 187749      1.0    7/9/1995 0:00:00         1610       CST    19.0
# 187771      1.0   6/10/1994 0:00:00         1840       CST    25.0
# 187795      1.0    3/9/1994 0:00:00         1755       CST    31.0
# 187847      1.0    7/6/1994 0:00:00          800       CST    39.0
# ...

# %%
# Out:
#   File "<ipython-input-26-45ba0fcf82fe>", line 1
#     print FATALITIES
#                    ^
# SyntaxError: Missing parentheses in call to 'print'
